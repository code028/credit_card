# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
import torch
from torch import nn, optim
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("dccc_prepared.csv")
data.head()
# Out:
#    LIMIT_BAL  EDUCATION  MARRIAGE       AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   0.080808   0.333333  0.666667  0.224138    0.2    0.2    0.2    0.2
# 1   0.040404   0.333333  0.333333  0.275862    0.2    0.2    0.2    0.2
# 2   0.040404   0.333333  0.333333  0.620690    0.1    0.2    0.1    0.2
# 3   0.040404   0.166667  0.666667  0.275862    0.2    0.2    0.2    0.2
# 4   0.494949   0.166667  0.666667  0.137931    0.2    0.2    0.2    0.2
#
#    PAY_5  PAY_6  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0    0.2    0.2  ...   0.173637   0.095470   0.272928  0.001738  0.000891
# 1    0.2    0.2  ...   0.186809   0.109363   0.283685  0.002290  0.001199
# 2    0.2    0.2  ...   0.179863   0.099633   0.275681  0.002290  0.021779
# 3    0.2    0.2  ...   0.178407   0.100102   0.276367  0.002862  0.001078
# 4    0.2    0.2  ...   0.671310   0.559578   0.625196  0.062961  0.023749
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0  0.001116  0.001610  0.002345  0.009458                           0
# 1  0.001339  0.001771  0.002506  0.001892                           0
# 2  0.011160  0.014493  0.001615  0.001284                           0
# 3  0.000733  0.001610  0.002345  0.001513                           0
# 4  0.042409  0.032591  0.032237  0.026047                           0
#
# [5 rows x 23 columns]

# %%
X = data.iloc[:,:-1]
y = data["default payment next month"]

# %%
X_new, X_test, y_new, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
dev_per = X_test.shape[0]/X_new.shape[0]
X_train, X_dev, y_train, y_dev = train_test_split(X_new, y_new, test_size=dev_per, random_state=0)

# %%
print("Training sets:",X_train.shape, y_train.shape)
print("Validation sets:",X_dev.shape, y_dev.shape)
print("Testing sets:",X_test.shape, y_test.shape)
# Out:
# Training sets: (28036, 22) (28036,)
# Validation sets: (9346, 22) (9346,)
# Testing sets: (9346, 22) (9346,)

# %%
X_dev_torch = torch.tensor(X_dev.values).float()
y_dev_torch = torch.tensor(y_dev.values)
X_test_torch = torch.tensor(X_test.values).float()
y_test_torch = torch.tensor(y_test.values)

# %%
class Classifier(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        self.hidden_1 = nn.Linear(input_size, 10)
        self.hidden_2 = nn.Linear(10, 10)
        self.hidden_3 = nn.Linear(10, 10)
        self.output = nn.Linear(10, 2)
        
    def forward(self, x):
        z = F.relu(self.hidden_1(x))
        z = F.relu(self.hidden_2(z))
        z = F.relu(self.hidden_3(z))
        out = F.log_softmax(self.output(z), dim=1)
        
        return out

# %%
model = Classifier(X_train.shape[1])
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

epochs = 50
batch_size = 128

# %%
train_losses, dev_losses, train_acc, dev_acc= [], [], [], []

for e in range(epochs):
    X_, y_ = shuffle(X_train, y_train)
    running_loss = 0
    running_acc = 0
    iterations = 0
    
    for i in range(0, len(X_), batch_size):
        iterations += 1
        b = i + batch_size
        X_batch = torch.tensor(X_.iloc[i:b,:].values).float()
        y_batch = torch.tensor(y_.iloc[i:b].values)
        
        pred = model(X_batch)
        loss = criterion(pred, y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        ps = torch.exp(pred)
        top_p, top_class = ps.topk(1, dim=1)
        running_acc += accuracy_score(y_batch, top_class)
        
    dev_loss = 0
    acc = 0

    # Turn off gradients for validation, saves memory and computations
    with torch.no_grad():
        pred_dev = model(X_dev_torch)
        dev_loss = criterion(pred_dev, y_dev_torch)

        ps_dev = torch.exp(pred_dev)
        top_p, top_class_dev = ps_dev.topk(1, dim=1)
        acc = accuracy_score(y_dev_torch, top_class_dev)

    train_losses.append(running_loss/iterations)
    dev_losses.append(dev_loss)
    train_acc.append(running_acc/iterations)
    dev_acc.append(acc)

    print("Epoch: {}/{}.. ".format(e+1, epochs),
          "Training Loss: {:.3f}.. ".format(running_loss/iterations),
          "Validation Loss: {:.3f}.. ".format(dev_loss),
          "Training Accuracy: {:.3f}.. ".format(running_acc/iterations),
          "Validation Accuracy: {:.3f}".format(acc))
# Out:
# Epoch: 1/50..  Training Loss: 0.673..  Validation Loss: 0.630..  Training Accuracy: 0.573..  Validation Accuracy: 0.671
# Epoch: 2/50..  Training Loss: 0.612..  Validation Loss: 0.606..  Training Accuracy: 0.673..  Validation Accuracy: 0.680
# Epoch: 3/50..  Training Loss: 0.598..  Validation Loss: 0.596..  Training Accuracy: 0.689..  Validation Accuracy: 0.688
# Epoch: 4/50..  Training Loss: 0.590..  Validation Loss: 0.588..  Training Accuracy: 0.694..  Validation Accuracy: 0.695
# Epoch: 5/50..  Training Loss: 0.584..  Validation Loss: 0.584..  Training Accuracy: 0.699..  Validation Accuracy: 0.698
# Epoch: 6/50..  Training Loss: 0.579..  Validation Loss: 0.582..  Training Accuracy: 0.703..  Validation Accuracy: 0.696
# Epoch: 7/50..  Training Loss: 0.580..  Validation Loss: 0.581..  Training Accuracy: 0.702..  Validation Accuracy: 0.696
# Epoch: 8/50..  Training Loss: 0.575..  Validation Loss: 0.580..  Training Accuracy: 0.703..  Validation Accuracy: 0.696
# Epoch: 9/50..  Training Loss: 0.574..  Validation Loss: 0.580..  Training Accuracy: 0.704..  Validation Accuracy: 0.697
# Epoch: 10/50..  Training Loss: 0.571..  Validation Loss: 0.578..  Training Accuracy: 0.707..  Validation Accuracy: 0.699
# Epoch: 11/50..  Training Loss: 0.573..  Validation Loss: 0.577..  Training Accuracy: 0.705..  Validation Accuracy: 0.701
# Epoch: 12/50..  Training Loss: 0.571..  Validation Loss: 0.577..  Training Accuracy: 0.704..  Validation Accuracy: 0.698
# Epoch: 13/50..  Training Loss: 0.569..  Validation Loss: 0.575..  Training Accuracy: 0.707..  Validation Accuracy: 0.698
# Epoch: 14/50..  Training Loss: 0.568..  Validation Loss: 0.575..  Training Accuracy: 0.705..  Validation Accuracy: 0.697
# Epoch: 15/50..  Training Loss: 0.569..  Validation Loss: 0.573..  Training Accuracy: 0.706..  Validation Accuracy: 0.699
# Epoch: 16/50..  Training Loss: 0.567..  Validation Loss: 0.573..  Training Accuracy: 0.709..  Validation Accuracy: 0.702
# Epoch: 17/50..  Training Loss: 0.566..  Validation Loss: 0.573..  Training Accuracy: 0.707..  Validation Accuracy: 0.698
# Epoch: 18/50..  Training Loss: 0.565..  Validation Loss: 0.572..  Training Accuracy: 0.708..  Validation Accuracy: 0.702
# Epoch: 19/50..  Training Loss: 0.564..  Validation Loss: 0.574..  Training Accuracy: 0.708..  Validation Accuracy: 0.698
# Epoch: 20/50..  Training Loss: 0.563..  Validation Loss: 0.570..  Training Accuracy: 0.708..  Validation Accuracy: 0.701
# Epoch: 21/50..  Training Loss: 0.564..  Validation Loss: 0.575..  Training Accuracy: 0.709..  Validation Accuracy: 0.693
# Epoch: 22/50..  Training Loss: 0.563..  Validation Loss: 0.569..  Training Accuracy: 0.708..  Validation Accuracy: 0.704
# Epoch: 23/50..  Training Loss: 0.561..  Validation Loss: 0.570..  Training Accuracy: 0.710..  Validation Accuracy: 0.700
# Epoch: 24/50..  Training Loss: 0.565..  Validation Loss: 0.568..  Training Accuracy: 0.708..  Validation Accuracy: 0.703
# Epoch: 25/50..  Training Loss: 0.561..  Validation Loss: 0.569..  Training Accuracy: 0.710..  Validation Accuracy: 0.703
# Epoch: 26/50..  Training Loss: 0.561..  Validation Loss: 0.567..  Training Accuracy: 0.711..  Validation Accuracy: 0.703
# Epoch: 27/50..  Training Loss: 0.559..  Validation Loss: 0.566..  Training Accuracy: 0.712..  Validation Accuracy: 0.705
# Epoch: 28/50..  Training Loss: 0.560..  Validation Loss: 0.566..  Training Accuracy: 0.710..  Validation Accuracy: 0.704
# Epoch: 29/50..  Training Loss: 0.560..  Validation Loss: 0.566..  Training Accuracy: 0.710..  Validation Accuracy: 0.705
# Epoch: 30/50..  Training Loss: 0.559..  Validation Loss: 0.571..  Training Accuracy: 0.712..  Validation Accuracy: 0.704
# Epoch: 31/50..  Training Loss: 0.561..  Validation Loss: 0.568..  Training Accuracy: 0.710..  Validation Accuracy: 0.704
# Epoch: 32/50..  Training Loss: 0.558..  Validation Loss: 0.567..  Training Accuracy: 0.712..  Validation Accuracy: 0.705
# Epoch: 33/50..  Training Loss: 0.558..  Validation Loss: 0.564..  Training Accuracy: 0.712..  Validation Accuracy: 0.705
# Epoch: 34/50..  Training Loss: 0.557..  Validation Loss: 0.566..  Training Accuracy: 0.714..  Validation Accuracy: 0.705
# Epoch: 35/50..  Training Loss: 0.558..  Validation Loss: 0.564..  Training Accuracy: 0.711..  Validation Accuracy: 0.705
# Epoch: 36/50..  Training Loss: 0.558..  Validation Loss: 0.564..  Training Accuracy: 0.713..  Validation Accuracy: 0.706
# Epoch: 37/50..  Training Loss: 0.559..  Validation Loss: 0.565..  Training Accuracy: 0.711..  Validation Accuracy: 0.706
# Epoch: 38/50..  Training Loss: 0.556..  Validation Loss: 0.564..  Training Accuracy: 0.714..  Validation Accuracy: 0.707
# Epoch: 39/50..  Training Loss: 0.556..  Validation Loss: 0.563..  Training Accuracy: 0.715..  Validation Accuracy: 0.706
# Epoch: 40/50..  Training Loss: 0.556..  Validation Loss: 0.563..  Training Accuracy: 0.713..  Validation Accuracy: 0.705
# Epoch: 41/50..  Training Loss: 0.556..  Validation Loss: 0.563..  Training Accuracy: 0.715..  Validation Accuracy: 0.706
# Epoch: 42/50..  Training Loss: 0.556..  Validation Loss: 0.564..  Training Accuracy: 0.714..  Validation Accuracy: 0.708
# Epoch: 43/50..  Training Loss: 0.554..  Validation Loss: 0.564..  Training Accuracy: 0.716..  Validation Accuracy: 0.708
# Epoch: 44/50..  Training Loss: 0.554..  Validation Loss: 0.562..  Training Accuracy: 0.718..  Validation Accuracy: 0.708
# Epoch: 45/50..  Training Loss: 0.554..  Validation Loss: 0.562..  Training Accuracy: 0.717..  Validation Accuracy: 0.709
# Epoch: 46/50..  Training Loss: 0.554..  Validation Loss: 0.562..  Training Accuracy: 0.715..  Validation Accuracy: 0.709
# Epoch: 47/50..  Training Loss: 0.556..  Validation Loss: 0.565..  Training Accuracy: 0.714..  Validation Accuracy: 0.707
# Epoch: 48/50..  Training Loss: 0.554..  Validation Loss: 0.563..  Training Accuracy: 0.714..  Validation Accuracy: 0.710
# Epoch: 49/50..  Training Loss: 0.554..  Validation Loss: 0.562..  Training Accuracy: 0.715..  Validation Accuracy: 0.709
# Epoch: 50/50..  Training Loss: 0.554..  Validation Loss: 0.562..  Training Accuracy: 0.715..  Validation Accuracy: 0.710

# %%
fig = plt.figure(figsize=(15, 5))
plt.plot(train_losses, label='Training loss')
plt.plot(dev_losses, label='Validation loss')
plt.legend(frameon=False, fontsize=15)
plt.show()

# %%
fig = plt.figure(figsize=(15, 5))
plt.plot(train_acc, label="Training accuracy")
plt.plot(dev_acc, label="Validation accuracy")
plt.legend(frameon=False, fontsize=15)
plt.show()
